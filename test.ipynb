# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lane = pd.read_csv('AAA_metrics_lane.csv')
lane.head()
# Out:
#    step laneID  WaitingTime          CO2
# 0    30    2_2          0.0     0.000000
# 1    30   -4_0          0.0  4361.108078
# 2    30    5_2          0.0     0.000000
# 3    30    7_2          0.0     0.000000
# 4    30    4_0          0.0     0.000000

# %%
lane_step = lane.groupby('step').agg({'WaitingTime':'mean','CO2':'mean'}).reset_index()
lane_step.head()
# Out:
#    step  WaitingTime          CO2
# 0    30     0.966667  1613.536058
# 1    60    10.416667  2796.022644
# 2    90    27.466667  3799.775021
# 3   120    54.450000  4366.523842
# 4   150    89.200000  4877.640977

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(lane_step['step'],lane_step['WaitingTime'],'-', label = 'WaitingTime')

ax2 = ax.twinx()
ax2.plot(lane_step['step'],lane_step['CO2'],'r', label = 'CO2')
fig.legend()

ax.set_xlabel('Time Step')
ax.set_ylabel('Waiting Time')
ax2.set_ylabel('CO2 Emission')
plt.show()

# %%
plt.plot()

# %%
vehicle = pd.read_csv('AAA_metrics_veh.csv')
vehicle.head()
# Out:
#    step  vehicleID   TimeLoss  AccumulatedWaitingTime
# 0    30          0  17.754256                    12.0
# 1    30         10  13.153120                     5.0
# 2    30         11  14.011005                     7.0
# 3    30         15  10.401284                     4.0
# 4    30         16   8.379678                     4.0

# %%
vehicle_step = vehicle.groupby('step').agg({'TimeLoss':'mean','AccumulatedWaitingTime':'mean'}).reset_index()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(vehicle_step['step'],vehicle_step['TimeLoss'],'-', label = 'TimeLoss')

ax2 = ax.twinx()
ax2.plot(vehicle_step['step'],vehicle_step['AccumulatedWaitingTime'],'r', label = 'AccumulatedWaitingTime')
fig.legend()

ax.set_xlabel('Time Step')
ax.set_ylabel('Time Loss')
ax2.set_ylabel('AccumulatedWaitingTime')
# Out:
# Text(0, 0.5, 'AccumulatedWaitingTime')

# %%
plt.plot(vehicle_step['step'],vehicle_step['TimeLoss'])

# %%
plt.plot(vehicle_step['step'],vehicle_step['TimeLoss'])
